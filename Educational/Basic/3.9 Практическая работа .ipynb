# %% [markdown]
# # Задача 1

# %% [markdown]
# 1 - e, 2 - d, 3 - a, 4 - d, 5 - b

# %%
from sympy import *
from sympy.plotting import plot

x = Symbol('x')

# %% [markdown]
# # Задача 2

# %% [markdown]
# 1. Все функции не четные
# 2. Нули функций: f1 - (-0.3), f2 - нет нулей (всегда больше нуля), f3 - 0, f4 - 0.0820849986238988, f5 - 3.58257569495584  и -5.58257569495584
# 3. f1 < 0 на промежутке (-oo < x) & (x < -0.3) и f1 > 0 на промежутке (-0.3 < x) & (x < oo)
# f2 > 0 на промежутке (-oo < x) & (x < oo)
# f2 > 0 на промежутке (-oo < x) & (x < oo)
# f4 < 0 на промежутке (0 < x) & (x < exp(-5/2)) и f4 > 0 на промежутке (x < oo) & (exp(-5/2) < x)
# f5 < 0 на промежутке (x < oo) & (3.58257569495584) < x)) | ((-oo < x) & (x < -5.58257569495584) и f5 > 0 на промежутке (x < 3.58257569495584) & (-5.58257569495584 < x)
# 4. Функции f1, f2, f3, f4 - на (-oo < x) & (x < oo), f5 возрастает на (-oo, -1) и убывает на (-1, -oo)

# %%
f1 = 5*x + 1.5
plot(f1)
print(solve(f1))
print(solve_univariate_inequality(f1<0, x))
print(solve_univariate_inequality(f1>0, x))
# Out:
# [-0.300000000000000]
# (-oo < x) & (x < -0.3)
# (-0.3 < x) & (x < oo)

# %%
f2 = 2*exp(0.2*x)
plot(f2)
print(solve(f2))
print(solve_univariate_inequality(f2<0, x))
print(solve_univariate_inequality(f2>0, x))
# Out:
# []
# False
# (-oo < x) & (x < oo)

# %%
f3 = 3 * sqrt(x)
plot(f)
print(solve(f3))
print(solve_univariate_inequality(f3<0, x))
print(solve_univariate_inequality(f3>0, x))
# Out:
# [0]
# False
# (0 < x) & (x < oo)

# %%
f4 = 2 * ln(x) + 5
plot(f4)
print(solve(f4))
print(solve_univariate_inequality(f4<0, x))
print(solve_univariate_inequality(f4>0, x))
# Out:
# [exp(-5/2)]
# (0 < x) & (x < exp(-5/2))
# (x < oo) & (exp(-5/2) < x)

# %%
exp(-5/2)
# Out:
# 0.0820849986238988

# %%
f5 = -5 * x**2 - 10*x + 100
plot(f5)
print(solve(f5))
print(solve_univariate_inequality(f5<0, x))
print(solve_univariate_inequality(f5>0, x))
# Out:
# [-1 + sqrt(21), -sqrt(21) - 1]
# ((x < oo) & (-1 + sqrt(21) < x)) | ((-oo < x) & (x < -sqrt(21) - 1))
# (x < -1 + sqrt(21)) & (-sqrt(21) - 1 < x)

# %%
-1 + sqrt(21)
# Out:
# -1 + sqrt(21)

# %%
sqrt(21).evalf()
# Out:
# 4.58257569495584

# %%
4.58257569495584-1
# Out:
# 3.58257569495584

# %%
(-5.58257569495584 + 3.58257569495584)/2
# Out:
# -1.0

# %%
from sympy import *

a0, a1, a2, a3, a4, a5 = symbols('a0, a1, a2, a3, a4, a5')
eq1_lp = a5*(-4)**5 + a4*(-4)**4 + a3*(-4)**3 + a2*(-4)**2 + a1*(-4) + a0 + 16729
eq2_lp = a5*(-3)**5 + a4*(-3)**4 + a3*(-3)**3 + a2*(-3)**2 + a1*(-3) + a0 + 3999
eq3_lp = a5*(-1)**5 + a4*(-1)**4 + a3*(-1)**3 + a2*(-1)**2 + a1*(-1) + a0 - 5
eq4_lp = a5*(1)**5 + a4*(1)**4 + a3*(1)**3 + a2*(1)**2 + a1*(1) + a0 - 1
eq5_lp = a5*(3)**5 + a4*(3)**4 + a3*(3)**3 + a2*(3)**2 + a1*(3) + a0 - 4005
eq6_lp = a5*(4)**5 + a4*(4)**4 + a3*(4)**3 + a2*(4)**2 + a1*(4) + a0 - 16735
nonlinsolve([eq1_lp, eq2_lp, eq3_lp, eq4_lp, eq5_lp, eq6_lp], [a5, a4, a3, a2, a1, a0])
# Out:
# {(16, 0, 7, 0, -25, 3)}

# %%
x = Symbol('x')
f2 = 16*x**5 + 7*x**3 - 25*x + 3
f2
# Out:
# 16*x**5 + 7*x**3 - 25*x + 3

# %%
plot(f2)
print(f'Нули функции {solve(f2)}')
print(f'Фунция меньше нуля на промежутках {solve_univariate_inequality(f2<0, x)}')
print(f'Фунция больше нуля на промежутках {solve_univariate_inequality(f2>0, x)}')
# Out:
# Нули функции [CRootOf(16*x**5 + 7*x**3 - 25*x + 3, 0), CRootOf(16*x**5 + 7*x**3 - 25*x + 3, 1), CRootOf(16*x**5 + 7*x**3 - 25*x + 3, 2), CRootOf(16*x**5 + 7*x**3 - 25*x + 3, 3), CRootOf(16*x**5 + 7*x**3 - 25*x + 3, 4)]
# Фунция меньше нуля на промежутках ((-oo < x) & (x < CRootOf(16*x**5 + 7*x**3 - 25*x + 3, 0))) | ((x < CRootOf(16*x**5 + 7*x**3 - 25*x + 3, 2)) & (CRootOf(16*x**5 + 7*x**3 - 25*x + 3, 1) < x))
# Фунция больше нуля на промежутках ((x < oo) & (CRootOf(16*x**5 + 7*x**3 - 25*x + 3, 2) < x)) | ((x < CRootOf(16*x**5 + 7*x**3 - 25*x + 3, 1)) & (CRootOf(16*x**5 + 7*x**3 - 25*x + 3, 0) < x))
