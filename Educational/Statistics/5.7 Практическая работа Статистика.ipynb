# %% [markdown]
# # Задача 2.1

# %%
from sympy import *
while True:
    x0 = int(input('Введите целое нечетное число '))
    if x0 % 2 == 0:
        print('Число не является нечетным')
    else:
        break
a = 8 - 3
M = 10**(int(log(x0,10) + 1))
x = [(a * x0) % M] 
for i in range(1, 101):
    x.append((a * tmp[i-1]) % M)
x
# Out:
# Введите целое нечетное число 8966547
# [4832735,
#  1486475,
#  2432375,
#  2161875,
#  809375,
#  4046875,
#  234375,
#  1171875,
#  859375,
#  4296875,
#  1484375,
#  2421875,
#  2109375,
#  546875,
#  2734375,
#  3671875,
#  3359375,
#  1796875,
#  3984375,
#  4921875,
#  4609375,
#  3046875,
#  234375,
#  1171875,
#  859375,
#  4296875,
#  1484375,
#  2421875,
#  2109375,
#  546875,
#  2734375,
#  3671875,
#  3359375,
#  1796875,
#  3984375,
#  4921875,
#  4609375,
#  3046875,
#  234375,
#  1171875,
#  859375,
#  4296875,
#  1484375,
#  2421875,
#  2109375,
#  546875,
#  2734375,
#  3671875,
#  3359375,
#  1796875,
#  3984375,
#  4921875,
#  4609375,
#  3046875,
#  234375,
#  1171875,
#  859375,
#  4296875,
#  1484375,
#  2421875,
#  2109375,
#  546875,
#  2734375,
#  3671875,
#  3359375,
#  1796875,
#  3984375,
#  4921875,
#  4609375,
#  3046875,
#  234375,
#  1171875,
#  859375,
#  4296875,
#  1484375,
#  2421875,
#  2109375,
#  546875,
#  2734375,
#  3671875,
#  3359375,
# ...

# %% [markdown]
# # Задача 2.2

# %%
x0 = 0.01
y = [(-1/4)*log(1-x0)]
for i in range(2,11):
    y.append((-1/4)*log(1-i*x0))
y
# Out:
# [0.00251258396337536,
#  0.00505067682937987,
#  0.00761480187117714,
#  0.0102054986300638,
#  0.0128233235968876,
#  0.0154688509295219,
#  0.0181426732087089,
#  0.0208454022347628,
#  0.0235776698678103,
#  0.0263401289144566]
