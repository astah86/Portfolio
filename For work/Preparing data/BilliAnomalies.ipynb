# %%
import os
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.special as sps
import warnings
from scipy.stats import kurtosis
from scipy.stats import skew
import statsmodels.api as sm
import time

# %matplotlib inline
plt.rcParams["figure.figsize"] = (9, 5)
warnings.filterwarnings("ignore")

# %%
pathnew = 'D:\\Michael\\Data\\Billionaires_May_2023\\Tickers without ammend\\'


for filename in os.listdir(pathnew):
    possize = pd.DataFrame()
    dat = pd.read_csv(pathnew + filename)
    possize[filename] = dat.iloc[:,7]
    
    sns.scatterplot( data=possize[filename])
        
    
    plt.title(filename[:-4])
    plt.show()

# %%
pathnew = 'C:\\Users\\Msi-1\\Desktop\\New folder (2)\\27B\\'
dat = pd.read_csv(pathnew + 'KerrNeilson.csv', parse_dates = ['FilingOpenDate'], dayfirst = False)
dat1 = dat[dat['FilingPositionValue'] >= np.percentile(dat['FilingPositionValue'] ,99)]
dat1.sort_values('FilingPositionValue', ascending = False )
