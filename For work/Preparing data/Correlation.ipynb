# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.special as sps
import warnings

# %%
sheets = 'Increase year'
df = pd.read_excel('D:\\Michael\\Data\\Ratings\\Billionaires\\Results.xlsx', sheet_name = sheets)
research_list = ['CAR', 'RAR', 'Max. Sys % Drawdown', '# Trades', 'Avg % Profit/Loss', 'Avg Bars Held', '% of Winners', 'FinalRankToBuy', 'DayHold']
corr_m = df[research_list].corr()
corr_m
# Out:
#                           CAR       RAR  Max. Sys % Drawdown      # Trades  \
# CAR                  1.000000  0.072555            -0.893002  8.791416e-01
# RAR                  0.072555  1.000000             0.168450  5.498536e-02
# Max. Sys % Drawdown -0.893002  0.168450             1.000000 -7.939026e-01
# # Trades             0.879142  0.054985            -0.793903  1.000000e+00
# Avg % Profit/Loss    0.257454  0.562713            -0.049664  1.102321e-01
# Avg Bars Held        0.288013 -0.098241            -0.331894  5.774004e-02
# % of Winners         0.115042  0.636197             0.036522  5.898362e-02
# FinalRankToBuy       0.624188 -0.355034            -0.736391  7.549872e-01
# DayHold              0.183261 -0.247342            -0.303167  1.026631e-16
#
#                      Avg % Profit/Loss  Avg Bars Held  % of Winners  \
# CAR                           0.257454       0.288013      0.115042
# RAR                           0.562713      -0.098241      0.636197
# ...

# %%
plt.figure(figsize=(17,15))
sns.heatmap(corr_m, center=0, annot=True)
# Out:
# <AxesSubplot:>
